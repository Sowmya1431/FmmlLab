# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmya1431/FmmlLab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 05:43:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   202MB/s    in 0.3s
#
# 2024-03-31 05:43:08 (202 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 37328  1703.10847v2  Most existing neural network models for music ...    cs
# 21556   1009.5736v4  A nonparametric kernel-based method for realiz...  stat
# 8399   1603.05027v3  Deep residual networks have emerged as a famil...    cs
# 6454   1702.04013v1  We study the performance of data-driven, a pri...    cs
# 6730   1705.08741v2  Background: Deep learning models are typically...  stat
# ...             ...                                                ...   ...
# 3727   1803.02865v1  Adjusting the learning rate schedule in stocha...  stat
# 25871  1512.01774v1  Recently, the dense binary pixel Gigavision ca...    cs
# 6731   1705.08821v2  Learning individual-level causal effects from ...  stat
# 30006  1711.04901v2  Along with the improvement of radar technologi...    cs
# 17111  1708.06022v1  Question answering (QA) systems are sensitive ...    cs
#
#                                                    title  year  \
# 37328  MidiNet: A Convolutional Generative Adversaria...  2017
# 21556                                 Kernel Bayes' rule  2010
# 8399         Identity Mappings in Deep Residual Networks  2016
# 6454   Is a Data-Driven Approach still Better than Ra...  2017
# 6730   Train longer, generalize better: closing the g...  2017
# ...                                                  ...   ...
# 3727   WNGrad: Learn the Learning Rate in Gradient De...  2018
# 25871      Image reconstruction from dense binary pixels  2015
# 6731   Causal Effect Inference with Deep Latent-Varia...  2017
# 30006  A Multiple Radar Approach for Automatic Target...  2017
# 17111      Learning to Paraphrase for Question Answering  2017
#
#                                                 keywords
# 37328  [generation, recurrent, convolutional, realist...
# 21556  [nonparametric, realizing, representations, pr...
# 8399   [extremely, architectures, compelling, converg...
# 6454   [performance, approaches, partitioning, classi...
# 6730   [background, typically, stochastic, estimated,...
# ...                                                  ...
# 3727   [adjusting, stochastic, important, unresolved,...
# 25871  [gigavision, introduced, emulating, photograph...
# 6731   [individual, observational, inferring, effecti...
# 30006  [improvement, technologies, automatic, recogni...
# 17111  [answering, sensitive, different, expresses, i...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 37328    [generation, recurrent, convolutional, realist...
# 21556    [nonparametric, realizing, representations, pr...
# 8399     [extremely, architectures, compelling, converg...
# 6454     [performance, approaches, partitioning, classi...
# 6730     [background, typically, stochastic, estimated,...
#                                ...
# 12465    [reinforcement, discounted, processes, continu...
# 11920    [protected, adversarial, perturbations, activa...
# 13466    [evolutionary, algorithm, importance, dimensio...
# 18511    [chronious, ubiquitous, management, obstructiv...
# 28007    [detection, important, processing, manipulatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8774 words.
# Out of those 4617 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3149ea4-d55a-4836-a4a3-75b27ff2b734" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3149ea4-d55a-4836-a4a3-75b27ff2b734")) {                    Plotly.newPlot(                        "a3149ea4-d55a-4836-a4a3-75b27ff2b734",                        [{"x":["conditional","available","adversarial","interesting","discriminator","comparably","recurrent","following","investigate","waveforms","generating","generative","knowledge","distributions","mechanism","realistic","convolutional","generator","possibilities","resulting","generation","generated","conditioning","representations","quantities","likelihood","consistency","reproducing","probabilities","including","representative","applications","posterior","nonparametric","expectation","expressed","characterized","functions","realizing","empirical","estimator","filtering","computation","presented","canonical","parametric","propagation","architectures","convergence","behaviors","compelling","importance","experiments","generalization","activation","extremely","connections","propagated","formulations","motivates","otherwise","classification","evaluated","approaches","classifiers","classifier","advantage","performance","significantly","benchmark","partitioning","established","performed","practices","additional","diffusion","eliminated","typically","relatively","background","concerning","algorithm","stochastic","estimated","significant","empirically","completely","contributions","hypothesis","therefore","techniques","persistent","degradation","increasing","logarithmically","normalization","generalize","different","landscape","initialization","statistical","conducted","phenomena","identifying","efficiency","principled","development","behaviour","approximate","representation","applicability","incorporating","unfortunately","differential","effective","estimates","efficient","predicting","equations","considerably","temperatures","computational","efficiently","expresses","application","unavailable","implemented","solutions","especially","demonstrate","inference","buildings","combination","automatic","decreases","difference","transcription","representational","broadcast","parameter","smoothing","constructed","configurations","simplicity","complicated","recognition","consistent","parameters","distribution","amortized","datapoint","suboptimality","imperfect","expressiveness","divergence","improving","determined","variational","approximating","furthermore","autoencoders","complexity","generalizing","approximation","accommodate","constraints","separation","processing","dictionaries","selection","magnitude","denoising","coefficient","algorithms","orthogonality","smoothness","regularized","requirements","previously","dictionary","sometimes","represented","dimension","representing","assumption","localized","described","rademacher","dimensions","questions","probabilistic","complements","perspective","optimizing","structured","introduce","objective","inconsistency","multivariate","adversary"],"y":[107,309,113,77,20,10,141,90,122,2,119,123,384,131,102,53,366,39,18,140,134,185,17,228,15,65,39,4,62,242,37,443,38,25,32,37,35,192,4,148,30,57,144,177,18,36,59,139,119,31,10,84,591,84,34,45,52,10,18,13,21,492,156,420,122,149,87,902,257,194,20,43,129,10,117,18,6,110,58,85,13,789,145,63,238,66,40,43,55,143,388,5,19,90,1,24,56,742,18,25,159,79,24,79,166,27,129,41,114,400,46,48,38,31,238,64,406,83,18,19,0,293,144,6,244,7,87,150,128,546,210,6,133,185,16,60,11,14,8,137,17,63,27,31,36,377,85,235,218,6,4,2,8,8,25,100,41,56,20,173,25,224,18,104,14,132,39,277,22,142,54,39,29,571,3,15,33,43,104,60,23,100,64,73,68,16,70,6,39,68,165,4,71,37,109,322,151,9,17,13],"type":"bar"},{"x":["conditional","available","adversaria ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4617,), (4617, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Real</span> <span style=''>time</span> <span style=''>Hand</span> <span style=''>Tracking</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.7368421052631579);'>Occlusion</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Egocentric</span> <span style=''>RGB</span> <span style=''>D</span> <span style=''>Sensor</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>real</span> <span style=''>time</span> <span style=''>robust</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>hand</span> <span style=''>pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>from</span> <span style=''>moving</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>egocentric</span> <span style=''>RGB</span> <span style=''>D</span> <span style=''>cameras</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>cluttered</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.5229357798165137);'>environments</span> <span style=''>Existing</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>fail</span> <span style=''>for</span> <span style=''>hand</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>cluttered</span> <span style=''>scenes</span> <span style=''>imaged</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>egocentric</span> <span style='background-color:rgba(0, 255, 0, 0.7894736842105263);'>viewpoints</span> <span style=''>common</span> <span style=''>for</span> <span style=''>virtual</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmented</span> <span style=''>reality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>uses</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsequently</span> <span style=''>applied</span> <span style='background-color:rgba(0, 255, 0, 0.6052631578947367);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(CNNs)</span> <span style=''>to</span> <span style=''>localize</span> <span style=''>the</span> <span style=''>hand</span> <span style=''>and</span> <span style=''>regress</span> <span style=''>3D</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.47692307692307695);'>locations</span> <span style=''>Hand</span> <span style='background-color:rgba(0, 255, 0, 0.7428571428571429);'>localization</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style=''>CNN</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>2D</span> <span style=''>position</span> <span style=''>of</span> <span style=''>the</span> <span style=''>hand</span> <span style=''>center</span> <span style=''>in</span> <span style=''>the</span> <span style=''>input</span> <span style=''>even</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>clutter</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>occlusions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.39130434782608703);'>localized</span> <span style=''>hand</span> <span style=''>position</span> <span style=''>together</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>Networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style=''>State</span> <span style=''>Space</span> <span style=''>Models</span> <br/><br/><span style=''>Gaussian</span> <span style=''>state</span> <span style=''>space</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style=''>decades</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>data</span> <span style=''>They</span> <span style=''>admit</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>have</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>and</span> <span style=''>enjoy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>widespread</span> <span style=''>adoption</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style=''>linear</span> <span style=''>and</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>state</span> <span style=''>space</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>variants</span> <span style=''>where</span> <span style=''>the</span> <span style=''>emission</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>modeled</span> <span style=''>by</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>learns</span> <span style=''>a</span> <span style=''>compiled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>network</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>to</span> <span style=''>mimic</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>We</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>performs</span> <span style='background-color:rgba(255, 0, 0, 0.5234042553191489);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.31707317073170743);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3972602739726027);'>converges</span> <span style=''>to</span> <span style=''>limit</span> <span style=''>cycles</span> <span style=''>for</span> <span style=''>deep</span> <span style=''>networks</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SGD)</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>believed</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>implicit</span> <span style='background-color:rgba(255, 0, 0, 0.30508474576271183);'>regularization</span> <span style=''>when</span> <span style=''>used</span> <span style=''>to</span> <span style=''>train</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>but</span> <span style=''>the</span> <span style=''>precise</span> <span style=''>manner</span> <span style=''>in</span> <span style=''>which</span> <span style=''>this</span> <span style=''>occurs</span> <span style=''>has</span> <span style=''>thus</span> <span style=''>far</span> <span style=''>been</span> <span style=''>elusive</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>SGD</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizes</span> <span style=''>an</span> <span style=''>average</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6161616161616161);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>weights</span> <span style=''>along</span> <span style=''>with</span> <span style=''>an</span> <span style=''>entropic</span> <span style='background-color:rgba(255, 0, 0, 0.30508474576271183);'>regularization</span> <span style=''>term</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>is</span> <span style=''>however</span> <span style=''>not</span> <span style=''>the</span> <span style=''>original</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>in</span> <span style=''>general</span> <span style=''>So</span> <span style=''>SGD</span> <span style=''>does</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.5234042553191489);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.31707317073170743);'>inference</span> <span style=''>but</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.32146037399821914);'>different</span> <span style=''>loss</span> <span style=''>than</span> <span style=''>the</span> <span style=''>one</span> <span style=''>used</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>Even</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprisingly</span> <span style=''>SGD</span> <span style=''>does</span> <span style=''>not</span> <span style=''>even</span> <span style=''>converge</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>sense</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>most</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Seglearn</span> <span style=''>A</span> <span style=''>Python</span> <span style=''>Package</span> <span style=''>for</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequences</span> <span style=''>and</span> <span style=''>Time</span> <span style=''>Series</span> <br/><br/><span style=''>Seglearn</span> <span style=''>is</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>python</span> <span style=''>package</span> <span style=''>for</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>time</span> <span style=''>series</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>using</span> <span style=''>a</span> <span style=''>sliding</span> <span style=''>window</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>approach</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>pipeline</span> <span style=''>for</span> <span style=''>tackling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>sequence</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contextual</span> <span style=''>data</span> <span style=''>This</span> <span style=''>package</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compatible</span> <span style=''>with</span> <span style=''>scikit</span> <span style=''>learn</span> <span style=''>and</span> <span style=''>is</span> <span style=''>listed</span> <span style=''>under</span> <span style=''>scikit</span> <span style=''>learn</span> <span style=''>Related</span> <span style=''>Projects</span> <span style=''>The</span> <span style=''>package</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>numpy</span> <span style=''>scipy</span> <span style=''>and</span> <span style=''>scikit</span> <span style=''>learn</span> <span style=''>Seglearn</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>under</span> <span style=''>the</span> <span style=''>BSD</span> <span style=''>3</span> <span style=''>Clause</span> <span style=''>License</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Documentation</span> <span style=''>includes</span> <span style=''>a</span> <span style=''>detailed</span> <span style=''>API</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>description</span> <span style=''>user</span> <span style=''>guide</span> <span style=''>and</span> <span style=''>examples</span> <span style=''>Unit</span> <span style=''>tests</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>high</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>code</span> <span style=''>coverage</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09581694672863783)
# 	architecture (0.081515909903468)
# 	experimental (0.142652842331069)
# 	segmentation (0.0775831247765463)
# 	knowledge (0.13728995352163031)
# 	representation (0.14301036825169824)
# 	different (0.26528423310690025)
# 	detection (0.12406149445834823)
# 	convolutional (0.13085448695030388)
# 	recognition (0.1347872720772256)
#
# Some Statistics words are:
# 	stochastic (0.12880678981527707)
# 	variables (0.13130304543185223)
# 	statistical (0.15327009485771342)
# 	theoretical (0.1597603594608088)
# 	estimation (0.17224163754368446)
# 	distribution (0.18222666000998503)
# 	algorithm (0.3969046430354468)
# 	dimensional (0.17873190214677984)
# 	inference (0.20219670494258613)
# 	regression (0.1797304043934099)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="38ad0516-8ea0-47c8-bf9c-906858cca51c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38ad0516-8ea0-47c8-bf9c-906858cca51c")) {                    Plotly.newPlot(                        "38ad0516-8ea0-47c8-bf9c-906858cca51c",                        [{"x":["conditional","available","adversarial","interesting","discriminator","comparably","recurrent","following","investigate","waveforms","generating","generative","knowledge","distributions","mechanism","realistic","convolutional","generator","possibilities","resulting","generation","generated","conditioning","representations","quantities","likelihood","consistency","reproducing","probabilities","including","representative","applications","posterior","nonparametric","expectation","expressed","characterized","functions","realizing","empirical","estimator","filtering","computation","presented","canonical","parametric","propagation","architectures","convergence","behaviors","compelling","importance","experiments","generalization","activation","extremely","connections","propagated","formulations","motivates","otherwise","classification","evaluated","approaches","classifiers","classifier","advantage","performance","significantly","benchmark","partitioning","established","performed","practices","additional","diffusion","eliminated","typically","relatively","background","concerning","algorithm","stochastic","estimated","significant","empirically","completely","contributions","hypothesis","therefore","techniques","persistent","degradation","increasing","logarithmically","normalization","generalize","different","landscape","initialization","statistical","conducted","phenomena","identifying","efficiency","principled","development","behaviour","approximate","representation","applicability","incorporating","unfortunately","differential","effective","estimates","efficient","predicting","equations","considerably","temperatures","computational","efficiently","expresses","application","unavailable","implemented","solutions","especially","demonstrate","inference","buildings","combination","automatic","decreases","difference","transcription","representational","broadcast","parameter","smoothing","constructed","configurations","simplicity","complicated","recognition","consistent","parameters","distribution","amortized","datapoint","suboptimality","imperfect","expressiveness","divergence","improving","determined","variational","approximating","furthermore","autoencoders","complexity","generalizing","approximation","accommodate","constraints","separation","processing","dictionaries","selection","magnitude","denoising","coefficient","algorithms","orthogonality","smoothness","regularized","requirements","previously","dictionary","sometimes","represented","dimension","representing","assumption","localized","described","rademacher","dimensions","questions","probabilistic","complements","perspective","optimizing","structured","introduce","objective","inconsistency","multivariate","adversary","surrogate","sequences","adversarially","approximations","prediction","computationally","minimization","alignment","predicted","properties","formulation","difficult","predictions","matchings","predictor","incremental","modelling","factorisation","population","exploration","completion","resources","specifically","exploitation","extracting","extracted","information","construction","inferring","compositional","processes","insufficient","subsequent","structure","designing","capability","implementation","promising","optimization","relativity","avoidance","challenges","introduced","multimodal","researchers","transformation","curvature","frequently","comparisons","excellent","extensive","prohibits","nonlinear","inter ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	temperatures
# 	elucidate
# 	coherently
# 	mislabeled
# 	informally
# 	faithfulness
# 	timescales
# 	irregularly
# 	assertion
# 	epidemics
# 	transplantation
# 	entropies
# 	simplemkl
# 	intersect
# 	reinterpret
# 	reseeding
# 	uncollapsed
# 	inflation
# 	predecessors
# 	streamline
# Some words which never appear in Statistics papers:
# 	avoidance
# 	converter
# 	newspapers
# 	unpredictable
# 	crowdsourcers
# 	diversities
# 	assistive
# 	reflection
# 	illuminating
# 	reparameterizations
# 	photometric
# 	certificates
# 	retrieves
# 	radiologists
# 	milliseconds
# 	gazetteers
# 	achievements
# 	awareness
# 	ameliorating
# 	pheromone

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0687083806425876e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
